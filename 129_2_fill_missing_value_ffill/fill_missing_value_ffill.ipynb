# %% [markdown]
# ###### 129_2_fill_missing_value_ffill

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(
    [
        80,
        100,
        79,
        np.nan,
        91,
    ],
    columns=[
        "point",
    ],
)
df
# Out:
#    point
# 0   80.0
# 1  100.0
# 2   79.0
# 3    NaN
# 4   91.0

# %%
df["point"].ffill()
# Out:
# 0     80.0
# 1    100.0
# 2     79.0
# 3     79.0
# 4     91.0
# Name: point, dtype: float64
