# %% [markdown]
# # 134-6 NumPy配列の要素の比較・抽出
#
# ## 1問目 NumPy配列とスカラーの比較

# %%
import numpy as np

# %%
scores = np.array([20 ,62, 78, 45, 85])
scores
# Out:
# array([20, 62, 78, 45, 85])

# %%
pass_status = scores >= 60
pass_status
# Out:
# array([False,  True,  True, False,  True])

# %%
(scores >= 60) & (scores < 80)
# Out:
# array([False,  True,  True, False, False])

# %%
passed_scores = scores[scores >= 60]
passed_scores
# Out:
# array([62, 78, 85])

# %%
scores >= 50
# Out:
# array([False,  True,  True, False,  True])

# %%
scores[scores >= 80]
# Out:
# array([85])

# %%
scores[scores < 60]
# Out:
# array([20, 45])

# %%
scores = np.array([20, 63, 78, 45, 85])

# %%
scores >= 50
# Out:
# array([False,  True,  True, False,  True])

# %%
scores = scores[scores >= 80]

# %%
scores
# Out:
# array([85])

# %%
scores = scores[scores < 60]
# Out:
# array([], dtype=int64)

# %%
scores
# Out:
# array([], dtype=int64)

# %%
import numpy as np

scores = np.array([20, 62, 78, 45, 85])

# %%
failed_scores = scores[scores < 60]
failed_scores
# Out:
# array([20, 45])

# %% [markdown]
# ## STEP1：1人分の点数と合格点を作る

# %%
import numpy as np

scores = np.array([20, 62, 78, 45, 85])
passing_scores = np.array([60, 60, 80, 60, 80])

# %%
pass_status_1d = scores >= passing_scores
pass_status_1d
# Out:
# array([False,  True, False, False,  True])

# %%
scores_2d = np.array([[20, 62, 78, 45, 85],
                      [65, 59, 90, 65, 92]])

# %%
scores_2d.shape
# Out:
# (2, 5)

# %%
pass_status_2d = scores_2d >= passing_scores
pass_status_2d
# Out:
# array([[False,  True, False, False,  True],
#        [ True, False,  True,  True,  True]])

# %% [markdown]
# ## 10. 演習問題

# %%
scores = np.array([70, 55, 82, 40, 90])
passing_scores = np.array([60, 60, 80, 60, 80])

# %%
scores >= passing_scores
# Out:
# array([ True, False,  True, False,  True])

# %%
scores[scores >= passing_scores]
# Out:
# array([70, 82, 90])

# %%
scores_2d = np.array([[70, 55, 82, 40, 90],
                      [50, 65, 79, 70, 81]])
passing_scores = np.array([60, 60, 80, 60, 80])

# %%
scores_2d >= passing_scores
# Out:
# array([[ True, False,  True, False,  True],
#        [False,  True, False,  True,  True]])
