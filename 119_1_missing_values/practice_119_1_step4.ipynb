# %%
import pandas as pd

df_log = pd.read_csv("dataset/product_log.csv")
df_log.head()
# Out:
#          Date  Num Product
# 0  2017-01-03  1.0       B
# 1  2017-01-06  2.0       B
# 2  2017-01-07  1.0       A
# 3  2017-01-11  2.0       A
# 4  2017-01-12  2.0       B

# %%
df_log_count = df_log.count()
df_log_count
# Out:
# Date       40
# Num        36
# Product    40
# dtype: int64

# %%
df_log_mean = df_log["Num"].mean()
df_log_mean
# Out:
# np.float64(3.5833333333333335)

# %%
df_log["Num"].sum()
# Out:
# np.float64(129.0)

# %%
df_log["Num"].isnull().sum()
# Out:
# np.int64(4)

# %%
df_log["Product"].count()
# Out:
# np.int64(40)
