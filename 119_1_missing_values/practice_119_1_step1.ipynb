# %%
# %matplotlib inline
import pandas as pd

df_log = pd.read_csv("dataset/product_log.csv")
df_log.head()
# Out:
#          Date  Num Product
# 0  2017-01-03  1.0       B
# 1  2017-01-06  2.0       B
# 2  2017-01-07  1.0       A
# 3  2017-01-11  2.0       A
# 4  2017-01-12  2.0       B

# %%
df_log.plot()
# Out:
# <Axes: >

# %%
df_log.plot.bar();

# %%
# %matplotlib inline
import pandas as pd

df_log = pd.read_csv("dataset/product_log.csv")
df_log.head(10)
# Out:
#          Date  Num Product
# 0  2017-01-03  1.0       B
# 1  2017-01-06  2.0       B
# 2  2017-01-07  1.0       A
# 3  2017-01-11  2.0       A
# 4  2017-01-12  2.0       B
# 5  2017-01-13  3.0       B
# 6  2017-01-15  2.0       B
# 7  2017-01-18  3.0       B
# 8  2017-01-20  2.0       B
# 9  2017-01-21  2.0       A

# %%
df_log["Num"].plot();

# %%
df_log["Num"].plot.bar();
