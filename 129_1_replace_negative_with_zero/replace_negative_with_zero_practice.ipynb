# %% [markdown]
# ###### 129_1_replace_negative_with_zero

# %%
import pandas as pd

# %%
sr = pd.Series([122, -3, 67])
sr
# Out:
# 0    122
# 1     -3
# 2     67
# dtype: int64

# %%
sr_result = sr.where(sr >= 0, 0)
sr_result
# Out:
# 0    122
# 1      0
# 2     67
# dtype: int64
