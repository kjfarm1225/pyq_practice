# %% [markdown]
# # 134-5 NumPyの便利な機能
#
# ## 1問目 統計値・要素間の差分

# %%
import numpy as np

temps = np.array([20, 22, 25, 28, 27,30, 24])
temps
# Out:
# array([20, 22, 25, 28, 27, 30, 24])

# %%
mean_temp = temps.mean()

# %%
mean_temp
# Out:
# np.float64(25.142857142857142)

# %%
max_temp = temps.max()
max_temp
# Out:
# np.int64(30)

# %%
diff_temps = np.diff(temps)
diff_temps
# Out:
# array([ 2,  3,  3, -1,  3, -6])

# %%
sales = np.array([100, 120, 90, 150, 130])

# %%
mean_sales = sales.mean()
mean_sales
# Out:
# np.float64(118.0)

# %%
max_sales = sales.max()
max_sales
# Out:
# np.int64(150)

# %%
diff_sales = np.diff(sales)
diff_sales
# Out:
# array([ 20, -30,  60, -20])

# %%
import numpy as np

defects = np.array([5, 7, 4, 4, 9, 6])

mean_defects = defects.mean()
max_defects = defects.max()
diff_defects = np.diff(defects)
sum_defects = defects.sum()

mean_defects, max_defects, diff_defects, sum_defects
# Out:
# (np.float64(5.833333333333333),
#  np.int64(9),
#  array([ 2, -3,  0,  5, -3]),
#  np.int64(35))

# %% [markdown]
# # 134-5 NumPyの便利な機能
#
# ## 2問目 ユニバーサルファンクション

# %%
import numpy as np

temps = np.array([20, 22, 25, 28, 27, 30, 24])
temps
# Out:
# array([20, 22, 25, 28, 27, 30, 24])

# %%
diff_temps = np.diff(temps)
diff_temps
# Out:
# array([ 2,  3,  3, -1,  3, -6])

# %%
abs_diff_temps = np.abs(diff_temps)
abs_diff_temps
# Out:
# array([2, 3, 3, 1, 3, 6])

# %%
np.abs(diff_temps)
# Out:
# array([2, 3, 3, 1, 3, 6])

# %%
result = []

for x in diff_temps:
    result.append(abs(x))

# %%
result
# Out:
# [np.int64(2), np.int64(3), np.int64(3), np.int64(1), np.int64(3), np.int64(6)]

# %%
np.abs(diff_temps)
# Out:
# array([2, 3, 3, 1, 3, 6])

# %%
import numpy as np

changes = np.array([5, -3, 8, -10, 0])

abs_changes = np.abs(changes)
abs_changes
# Out:
# array([ 5,  3,  8, 10,  0])

# %%
import numpy as np

defect_changes = np.array([2, -1, 0, 5, -3])
abs_defect_changes = np.abs(defect_changes)
abs_defect_changes
# Out:
# array([2, 1, 0, 5, 3])

# %% [markdown]
# # 134-5 NumPyの便利な機能
#
# ## 3問目 形状の変換

# %%
import numpy as np

temps = np.array([20, 22, 25, 28, 27, 30, 24, 25, 26, 32, 31, 30, 29, 25])
temps
# Out:
# array([20, 22, 25, 28, 27, 30, 24, 25, 26, 32, 31, 30, 29, 25])

# %%
temps.shape
# Out:
# (14,)

# %%
temps_week = temps.reshape(2, 7)
temps_week
# Out:
# array([[20, 22, 25, 28, 27, 30, 24],
#        [25, 26, 32, 31, 30, 29, 25]])

# %%
temps_week.shape
# Out:
# (2, 7)

# %%
temps_1d = temps_week.flatten()
temps_1d
# Out:
# array([20, 22, 25, 28, 27, 30, 24, 25, 26, 32, 31, 30, 29, 25])

# %%
import numpy as np

sales = np.array([100, 120, 110, 130, 150, 140, 160, 170, 180, 190, 200, 210])

sales_2d = sales.reshape((3, 4))
sales_2d
# Out:
# array([[100, 120, 110, 130],
#        [150, 140, 160, 170],
#        [180, 190, 200, 210]])

# %%
sales_1d = sales_2d.flatten()

# %%
sales_1d
# Out:
# array([100, 120, 110, 130, 150, 140, 160, 170, 180, 190, 200, 210])
