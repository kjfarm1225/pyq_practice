# %%
import pandas as pd

df = pd.DataFrame(
    [
        ["Alice", "", 87],
        ["Alice", "", 72],
        ["Bob", "", 65],
        ["Bob", "", 92],
    ],
    columns=["Name", "Subject", "Point"],
)

df[["Name"]]
# Out:
#     Name
# 0  Alice
# 1  Alice
# 2    Bob
# 3    Bob
