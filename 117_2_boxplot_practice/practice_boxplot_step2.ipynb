# %%
# %matplotlib inline
import pandas as pd

# %%
df_case_log = pd.read_csv("dataset/case_log.csv")
df_case_log.head()
# Out:
#          Date  Num Product  Case
# 0  2017-01-03  1.0       B    15
# 1  2017-01-06  2.0       B    15
# 2  2017-01-07  1.0       A    15
# 3  2017-01-08  3.0       C    20
# 4  2017-01-09  2.0       A    20

# %%
df_case_log.hist(bins=10);

# %%
df_case_log.plot.scatter("Num", "Case");

# %%
pd.plotting.scatter_matrix(df_case_log);

# %%
df_corr = df_case_log.corr(numeric_only=True)
df_corr
# Out:
#            Num      Case
# Num   1.000000  0.845375
# Case  0.845375  1.000000
