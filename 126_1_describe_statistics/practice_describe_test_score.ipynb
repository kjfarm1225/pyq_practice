# %% [markdown]
# ###### 126-1: 列ごとの統計量を確認するには」

# %%
import numpy as numpy
import pandas as pd

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(
    [
        ["Alice", "国語", 87],
        ["Alice", "数学", np.nan],
        ["Bob", "国語", 65],
        ["Bob", "数学", 92],
    ],
    columns=["Name", "Subject", "Point"],
)

df.describe()
# Out:
#            Point
# count   3.000000
# mean   81.333333
# std    14.364308
# min    65.000000
# 25%    76.000000
# 50%    87.000000
# 75%    89.500000
# max    92.000000
