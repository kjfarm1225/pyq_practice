# %%
import numpy as np

sales_1d = np.array([100, 120, 110])
sales_1d
# Out:
# array([100, 120, 110])

# %%
sales_head = sales_1d[0]
sales_head
# Out:
# np.int64(100)

# %%
sales_tail = sales_1d[-1]
sales_tail
# Out:
# np.int64(110)

# %%
sales_after_1 = sales_1d[1:3]
sales_after_1
# Out:
# array([120, 110])

# %%
sales_0_2 = sales_1d[[0, 2]]
sales_0_2
# Out:
# array([100, 110])

# %%
sales_2d = np.array([[100, 120, 110],
                     [150, 140, 130]])
sales_2d
# Out:
# array([[100, 120, 110],
#        [150, 140, 130]])

# %%
sales_row = sales_2d[0]
sales_row
# Out:
# array([100, 120, 110])

# %%
sales_shop1_day2 = sales_2d[0, 1]
sales_shop1_day2
# Out:
# np.int64(120)

# %%
sales_col = sales_2d[:, 1]
sales_col
# Out:
# array([120, 140])

# %%
sales_all_after_day2 = sales_2d[:, 1:]
sales_all_after_day2
# Out:
# array([[120, 110],
#        [140, 130]])

# %%
sales_all_0_2 = sales_2d[:, [0, 2]]
sales_all_0_2
# Out:
# array([[100, 110],
#        [150, 130]])

# %%
import numpy as np

data = np.array([10, 20, 30, 40])

# %%
data[0]
# Out:
# np.int64(10)

# %%
data[-1]
# Out:
# np.int64(40)

# %%
data[1:]
# Out:
# array([20, 30, 40])

# %%
data[[0, 2]]
# Out:
# array([10, 30])

# %%
scores = np.array(
    [[70, 80, 90],
     [60, 75, 85],
     [95, 88, 92]]
)

# %%
scores[0]
# Out:
# array([70, 80, 90])

# %%
scores[1, 1]
# Out:
# np.int64(75)

# %%
scores[:, 1]
# Out:
# array([80, 75, 88])

# %%
scores[:, [0, 2]]
# Out:
# array([[70, 90],
#        [60, 85],
#        [95, 92]])

# %%
import numpy as np
sales_1d = np.array([100, 120, 110])
sales_1d
# Out:
# array([100, 120, 110])

# %%
sales_1d[0] = 10
sales_1d
# Out:
# array([ 10, 120, 110])

# %%
sales_1d[1:] = 200
sales_1d
# Out:
# array([ 10, 200, 200])

# %%
sales_2d = np.array(
    [[100, 120, 110],
     [150, 140, 130]]
)

# %%
sales_2d
# Out:
# array([[100, 120, 110],
#        [150, 140, 130]])

# %%
sales_2d[0, 1] = 200

# %%
sales_2d
# Out:
# array([[100, 200, 110],
#        [150, 140, 130]])

# %%
sales_2d[0] = [201, 202, 203]
sales_2d
# Out:
# array([[201, 202, 203],
#        [150, 140, 130]])

# %%
sales_2d[1] = 300
sales_2d
# Out:
# array([[201, 202, 203],
#        [300, 300, 300]])

# %%
sales_2d[:, 2] = 0
sales_2d
# Out:
# array([[201, 202,   0],
#        [300, 300,   0]])

# %%
import numpy as np

data = np.array([10, 20, 30, 40])

# %%
data[0] = 100
data
# Out:
# array([100,  20,  30,  40])

# %%
scores = np.array(
    [[70, 80, 90],
     [60, 75, 85],
     [95, 88, 92]]
)

# %%
scores[0 ,1] = 100
scores
# Out:
# array([[ 70, 100,  90],
#        [ 60,  75,  85],
#        [ 95,  88,  92]])

# %%
scores[1] = [61, 76, 86]
scores
# Out:
# array([[ 70, 100,  90],
#        [ 61,  76,  86],
#        [ 95,  88,  92]])

# %%
scores[:, 2] = 0
scores
# Out:
# array([[ 70, 100,   0],
#        [ 61,  76,   0],
#        [ 95,  88,   0]])

# %%
stock = np.array(
    [[5, 3, 6],
    [3, 4, 9]]
)

# %%
stock[0, 0] = 10
stock
# Out:
# array([[10,  3,  6],
#        [ 3,  4,  9]])

# %%
stock[1] = 0
stock
# Out:
# array([[10,  3,  6],
#        [ 0,  0,  0]])

# %%
stock[:, 1] = 99
stock
# Out:
# array([[10, 99,  6],
#        [ 0, 99,  0]])
