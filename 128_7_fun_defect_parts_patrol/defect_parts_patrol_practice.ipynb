# %% [markdown]
# ###### 128_7_fun_defect_parts_patrol

# %%
import pandas as pd

# %%
df = pd.DataFrame(
    [
        ["D001", "J69P", "MELMB", "Line1", "コイル/Buck-IC", "RH Lo不灯", 5],
        ["D002", "J69P", "MELMB", "Line1", "コイル", "RH Hi/Lo不灯", 4],
        ["D003", "J69P", "WSE", "Line2", "Buck-IC/MCU", "全灯火不点灯", 5],
        ["D004", "310D", "GSE", "Line1", "はんだ/コネクタ", "点灯不安定", 3],
        ["D005", "310D", "ISE", "Line2", "異物", "点灯不安定", 2],
        ["D006", "J69P", "GSE", "Line1", "コイル/異物", "RH Lo不灯", 4],
        ["D007", "310D", "WSE", "Line2", "NTF", "再現せず", 1],
        ["D008", "J69P", "ISE", "Line1", "コイル/Buck-IC/MCU", "RH Lo不灯", 5],
        ["D009", "310D", "MELMB", "Line2", "はんだ/異物", "点灯不安定", 3],
        ["D010", "J69P", "WSE", "Line1", "コイル/Buck-IC", "RH Lo不灯", 4],
    ],
    columns=[
        "defect_id",
        "project",
        "site",
        "line",
        "確認部品",
        "symptom",
        "risk_score",
    ],
)
df
# Out:
#   defect_id project   site   line             確認部品     symptom  risk_score
# 0      D001    J69P  MELMB  Line1      コイル/Buck-IC     RH Lo不灯           5
# 1      D002    J69P  MELMB  Line1              コイル  RH Hi/Lo不灯           4
# 2      D003    J69P    WSE  Line2      Buck-IC/MCU      全灯火不点灯           5
# 3      D004    310D    GSE  Line1         はんだ/コネクタ       点灯不安定           3
# 4      D005    310D    ISE  Line2               異物       点灯不安定           2
# 5      D006    J69P    GSE  Line1           コイル/異物     RH Lo不灯           4
# 6      D007    310D    WSE  Line2              NTF        再現せず           1
# 7      D008    J69P    ISE  Line1  コイル/Buck-IC/MCU     RH Lo不灯           5
# 8      D009    310D  MELMB  Line2           はんだ/異物       点灯不安定           3
# 9      D010    J69P    WSE  Line1      コイル/Buck-IC     RH Lo不灯           4

# %%
#cell 3
df["確認部員"] = df["確認部品"].str.split("/")
df
# Out:
#   defect_id project   site   line             確認部品     symptom  risk_score  \
# 0      D001    J69P  MELMB  Line1      コイル/Buck-IC     RH Lo不灯           5
# 1      D002    J69P  MELMB  Line1              コイル  RH Hi/Lo不灯           4
# 2      D003    J69P    WSE  Line2      Buck-IC/MCU      全灯火不点灯           5
# 3      D004    310D    GSE  Line1         はんだ/コネクタ       点灯不安定           3
# 4      D005    310D    ISE  Line2               異物       点灯不安定           2
# 5      D006    J69P    GSE  Line1           コイル/異物     RH Lo不灯           4
# 6      D007    310D    WSE  Line2              NTF        再現せず           1
# 7      D008    J69P    ISE  Line1  コイル/Buck-IC/MCU     RH Lo不灯           5
# 8      D009    310D  MELMB  Line2           はんだ/異物       点灯不安定           3
# 9      D010    J69P    WSE  Line1      コイル/Buck-IC     RH Lo不灯           4
#
#                   確認部員
# 0       [コイル, Buck-IC]
# 1                [コイル]
# 2       [Buck-IC, MCU]
# 3          [はんだ, コネクタ]
# ...

# %%
#cell4
