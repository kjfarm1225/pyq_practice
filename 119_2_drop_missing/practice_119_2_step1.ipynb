# %%
import pandas as pd

df_log = pd.read_csv("dataset/product_log.csv")
df_log.head()
# Out:
#          Date  Num Product
# 0  2017-01-03  1.0       B
# 1  2017-01-06  2.0       B
# 2  2017-01-07  1.0       A
# 3  2017-01-11  2.0       A
# 4  2017-01-12  2.0       B

# %%
df_log.count()
# Out:
# Date       40
# Num        36
# Product    40
# dtype: int64

# %%
df_log_dropna = df_log.dropna()
df_log_dropna.count()
# Out:
# Date       36
# Num        36
# Product    36
# dtype: int64

# %%
df_log_dropna2 = df_log.dropna(axis=1)
df_log_dropna2.count()
# Out:
# Date       40
# Product    40
# dtype: int64

# %%
df_log_dropna3 = df_log.dropna(subset=["Date", "Product"])
df_log_dropna3.count()
# Out:
# Date       40
# Num        36
# Product    40
# dtype: int64

# %%
df_log.count()
# Out:
# Date       40
# Num        36
# Product    40
# dtype: int64

# %%
df_log.dropna(inplace=True)
df_log.count()
# Out:
# Date       36
# Num        36
# Product    36
# dtype: int64
