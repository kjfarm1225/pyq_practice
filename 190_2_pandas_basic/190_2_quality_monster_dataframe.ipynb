# %% [markdown]
# ## 実務演習問題

# %%
import pandas as pd

# %%
df_monster = pd.DataFrame({
    "site": ["melmb", "wse", "gse", "ise", "sus"],
    "product": ["lcm", "lcm", "lcm", "lcm", "lcm"],
    "production": [10000, 12000, 9000, 8000, 15000],
    "defects": [5, 12, 9, 2, 20],
    "monster": ["ネジゆるみドラゴン", "ハンダ不足スライム", "コネクタずれゴブリン", "ラベル間違いにゃー", "点灯しないゾンビ"]
})

df_monster.head()

df_monster["ppm"] = (df_monster["defects"] / df_monster["production"] * 1000000).round(1)
df_monster["危険度"] = ["注意", "危険", "危険", "良好", "長期件"]
df_monster.columns = ["拠点", "製品", "生産数", "不良数", "品質モンスタ", "ppm", "危険度"]


df_monster
# Out:
#       拠点   製品    生産数  不良数      品質モンスタ     ppm  危険度
# 0  melmb  lcm  10000    5   ネジゆるみドラゴン   500.0   注意
# 1    wse  lcm  12000   12   ハンダ不足スライム  1000.0   危険
# 2    gse  lcm   9000    9  コネクタずれゴブリン  1000.0   危険
# 3    ise  lcm   8000    2   ラベル間違いにゃー   250.0   良好
# 4    sus  lcm  15000   20    点灯しないゾンビ  1333.3  長期件
