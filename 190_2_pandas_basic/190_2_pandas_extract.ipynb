# %%
import pandas as pd

df = pd.read_csv("./input/python_workshop.csv")
df.head()
# Out:
#                                       イベント名         開催日                  会場  \
# 0  GAE (Go/Python) もくもく勉強会 in 横浜タネマキ vol.56  2018-08-19                タネマキ
# 1           【上級】論文輪読&実装会 強化学習 DQN 2018/8/19  2018-08-19  (株)HCI 本社工場 2F 会議室
# 2          人工知能を使ったリアルタイム物体検出でIoTを実践するハンズオン  2018-08-19             江東区産業会館
# 3         『Pythonによるクローラー＆スクレイピング入門』読書会 #01  2018-08-19       蕨市民会館（303会議室）
# 4       機械学習を始めるためのpythonデータ分析実践（機械学習モデル構築）  2018-08-19    スキルアップビデオテクノロジーズ
#
#    参加者数
# 0     6
# 1    10
# 2     5
# 3     0
# 4     7

# %%
df.tail()
# Out:
#                                            イベント名         開催日  \
# 293               Python勉強会（numpy 、Ansible、囲碁AI）  2018-07-01
# 294        【名古屋開催】【学生限定】初心者歓迎！PythonでBotを作ってみよう！  2018-07-01
# 295  Tokyo Quantopian User Group Vol.04 商品先物を学ぼう  2018-07-01
# 296   【未経験者・初心者向け】Python+Jupyterで学ぶプログラミングの基礎 #6  2018-07-01
# 297             機械学習を始めるためのpythonデータ分析実践（機械学習直前）  2018-07-01
#
#                    会場  参加者数
# 293             未来会議室     7
# 294   ヤフー株式会社 名古屋オフィス    26
# 295   株式会社Smart Trade    15
# 296            水道橋駅周辺     6
# 297  スキルアップビデオテクノロジーズ     9

# %%
df[:10]
# Out:
#                                                イベント名         開催日  \
# 0           GAE (Go/Python) もくもく勉強会 in 横浜タネマキ vol.56  2018-08-19
# 1                    【上級】論文輪読&実装会 強化学習 DQN 2018/8/19  2018-08-19
# 2                   人工知能を使ったリアルタイム物体検出でIoTを実践するハンズオン  2018-08-19
# 3                  『Pythonによるクローラー＆スクレイピング入門』読書会 #01  2018-08-19
# 4                機械学習を始めるためのpythonデータ分析実践（機械学習モデル構築）  2018-08-19
# 5                                      塩尻MLもくもく会 #07  2018-08-18
# 6                           Python機械学習勉強会in新潟Restart  2018-08-18
# 7                                        PyCPA第3回勉強会  2018-08-18
# 8                    【8月期 基礎数学シリーズ】機械学習・深層学習のための線形代数  2018-08-18
# 9  【eLV】ICTを支える「考え方」シリーズ：S05-A物理学の考え方 (時空・ベクトル・テン...  2018-08-18
#
#                         会場  参加者数
# 0                     タネマキ     6
# 1       (株)HCI 本社工場 2F 会議室    10
# 2                  江東区産業会館     5
# 3            蕨市民会館（303会議室）     0
# 4         スキルアップビデオテクノロジーズ     7
# 5  市民交流センターえんぱーく 2F 会議室203     7
# ...

# %%
df[20:25]
# Out:
#                                      イベント名         開催日  \
# 20  朝活Python 簡単スクレイピング（後編） in 秋葉原（秋葉原スクエア）  2018-08-17
# 21       夜活Python Webスクレイピング前編（0816） in 池袋  2018-08-16
# 22      量子化学計算集中合宿２！OpenFermion+Cirqを一日中触る  2018-08-16
# 23  朝活Python 簡単スクレイピング（前編） in 秋葉原（秋葉原スクエア）  2018-08-16
# 24                 【神田に移転！】Pythonアルゴリズム勉強会  2018-08-15
#
#                                   会場  参加者数
# 20             【秋葉原/浅草橋】秋葉原スクエア403号室    12
# 21  池袋サンシャインシティ tully's coffee  アルパ店     5
# 22                           MDR株式会社    19
# 23             【秋葉原/浅草橋】秋葉原スクエア403号室     8
# 24                   株式会社Smart Trade    18

# %%
df.loc[0:10, ["イベント名", "参加者数"]]
# Out:
#                                                 イベント名  参加者数
# 0            GAE (Go/Python) もくもく勉強会 in 横浜タネマキ vol.56     6
# 1                     【上級】論文輪読&実装会 強化学習 DQN 2018/8/19    10
# 2                    人工知能を使ったリアルタイム物体検出でIoTを実践するハンズオン     5
# 3                   『Pythonによるクローラー＆スクレイピング入門』読書会 #01     0
# 4                 機械学習を始めるためのpythonデータ分析実践（機械学習モデル構築）     7
# 5                                       塩尻MLもくもく会 #07     7
# 6                            Python機械学習勉強会in新潟Restart    25
# 7                                         PyCPA第3回勉強会     8
# 8                     【8月期 基礎数学シリーズ】機械学習・深層学習のための線形代数     0
# 9   【eLV】ICTを支える「考え方」シリーズ：S05-A物理学の考え方 (時空・ベクトル・テン...     5
# 10                                    fin-pyもくもく会 #18    14

# %%
df.iloc[0:10, [0, 3]]
# Out:
#                                                イベント名  参加者数
# 0           GAE (Go/Python) もくもく勉強会 in 横浜タネマキ vol.56     6
# 1                    【上級】論文輪読&実装会 強化学習 DQN 2018/8/19    10
# 2                   人工知能を使ったリアルタイム物体検出でIoTを実践するハンズオン     5
# 3                  『Pythonによるクローラー＆スクレイピング入門』読書会 #01     0
# 4                機械学習を始めるためのpythonデータ分析実践（機械学習モデル構築）     7
# 5                                      塩尻MLもくもく会 #07     7
# 6                           Python機械学習勉強会in新潟Restart    25
# 7                                        PyCPA第3回勉強会     8
# 8                    【8月期 基礎数学シリーズ】機械学習・深層学習のための線形代数     0
# 9  【eLV】ICTを支える「考え方」シリーズ：S05-A物理学の考え方 (時空・ベクトル・テン...     5
