# %%
s = input("> ")
print("入力された文字列は", s, "です。")
# Out:
# 入力された文字列は kajima です。

# %%
s = input("> ")

print("入力された文字:", s)
print("文字数:", len(s))
# Out:
# 入力された文字: shokichi
# 文字数: 8

# %%
s = input("> ")

while s != "":
    print("あなたが入力したのは", s, "です")
    s = input("> ")
# Out:
# あなたが入力したのは chie です
# あなたが入力したのは kokro です
# あなたが入力したのは wakaba です
# あなたが入力したのは good family です

# %%
while s := input("> "):
    print("あなたがにゅうりょくしたのは", s, "です")
# Out:
# あなたがにゅうりょくしたのは suzuki です
# あなたがにゅうりょくしたのは tanaka です
# あなたがにゅうりょくしたのは yamada です

# %%
s = input(">")
print("入力は", s, "です。")
# Out:
# 入力は かじま です。

# %%
s = input("> ")

while s != "":
    print("入力されたもじは", s, "です")
    print("文字数:", len(s), "です")
    s = input("> ")
# Out:
# 入力されたもじは kj です
# 文字数: 2 です
# 入力されたもじは chie です
# 文字数: 4 です
# 入力されたもじは kokoro です
# 文字数: 6 です
# 入力されたもじは wakaba です
# 文字数: 6 です

# %%
s = input("> ")

while s != "":
    print("あなたが入力したのは", s, "です")
    s = input("> ")

print("終了します。")
# Out:
# あなたが入力したのは 梶間博文 です
# 終了します。
