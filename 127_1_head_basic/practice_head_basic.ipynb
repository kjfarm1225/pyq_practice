# %% [markdown]
# ###### 127-1: データの先頭を取得するには

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(
    [
          ["Alice", "国語", 87],
        ["Alice", "数学", np.nan],
        ["Bob", "国語", 65],
        ["Bob", "数学", 92],
    ],
    columns=["Name", "Subject", "Score"],
)
df.head(2)
# Out:
#     Name Subject  Score
# 0  Alice      国語   87.0
# 1  Alice      数学    NaN
