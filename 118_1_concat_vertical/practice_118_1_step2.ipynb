# %%
# %run practice_118_1_step1.ipynb
df3.head()
# Out:
#        Date Name  Size  Price
# 0  2017/1/3    A     3    100
# 1  2017/2/4    B     4    200
# 2  2017/3/5    A     5    300

# %%
df5 = pd.DataFrame([[0], [0], [-1]], columns=['Extra'])
df5
# Out:
#    Extra
# 0      0
# 1      0
# 2     -1

# %%
df6 = pd.concat([df3, df5], axis=1)
df6
# Out:
#        Date Name  Size  Price  Extra
# 0  2017/1/3    A     3    100      0
# 1  2017/2/4    B     4    200      0
# 2  2017/3/5    A     5    300     -1

# %%
df7 =df3.copy()
df7['Extra'] = [0, 0, -1]
df7
# Out:
#        Date Name  Size  Price  Extra
# 0  2017/1/3    A     3    100      0
# 1  2017/2/4    B     4    200      0
# 2  2017/3/5    A     5    300     -1

# %%
df7 = df3.copy()

# %%
df7['Extra'] = [0, 0, -1]

# %%
df6
# Out:
#        Date Name  Size  Price  Extra
# 0  2017/1/3    A     3    100      0
# 1  2017/2/4    B     4    200      0
# 2  2017/3/5    A     5    300     -1

# %%
df7
# Out:
#        Date Name  Size  Price  Extra
# 0  2017/1/3    A     3    100      0
# 1  2017/2/4    B     4    200      0
# 2  2017/3/5    A     5    300     -1

# %%
(df6 == df7).all().all()
# Out:
# np.True_

# %%
df_a = pd.DataFrame(
    [['Sato', 80], ['Suzuki', 90],['Tanaka', 70]],
    columns=['Name', 'Score']
)

# %%
df_a
# Out:
#      Name  Score
# 0    Sato     80
# 1  Suzuki     90
# 2  Tanaka     70

# %%
df_b = pd.DataFrame(
    [['A'],['B'],['C']],
    columns=['Rank']
)

# %%
df_b
# Out:
#   Rank
# 0    A
# 1    B
# 2    C

# %%
df_c = pd.concat([df_a, df_b], axis=1)
df_c
# Out:
#      Name  Score Rank
# 0    Sato     80    A
# 1  Suzuki     90    B
# 2  Tanaka     70    C

# %%
df_d = df_a.copy()

# %%
df_d
# Out:
#      Name  Score
# 0    Sato     80
# 1  Suzuki     90
# 2  Tanaka     70

# %%
df_d['Rank'] = ['A', 'B', 'C']
df_d
# Out:
#      Name  Score Rank
# 0    Sato     80    A
# 1  Suzuki     90    B
# 2  Tanaka     70    C

# %%
(df_c == df_d).all().all()
# Out:
# np.True_

# %%
df_5 = pd.DataFrame([[1],[2],[3]], columns=['Extra'])
df_5
# Out:
#    Extra
# 0      1
# 1      2
# 2      3

# %%
df5 = pd.DataFrame([[1], [2], [3]], columns=['Extra'])
df6 = pd.concat([df3, df5], axis=1)
df6
# Out:
#        Date Name  Size  Price  Extra
# 0  2017/1/3    A     3    100      1
# 1  2017/2/4    B     4    200      2
# 2  2017/3/5    A     5    300      3

# %%
df7 = df3.copy()

# %%
df7
# Out:
#        Date Name  Size  Price
# 0  2017/1/3    A     3    100
# 1  2017/2/4    B     4    200
# 2  2017/3/5    A     5    300

# %%
df3.shape
# Out:
# (3, 4)

# %%
df6.shape
# Out:
# (3, 5)

# %%
df3
# Out:
#        Date Name  Size  Price
# 0  2017/1/3    A     3    100
# 1  2017/2/4    B     4    200
# 2  2017/3/5    A     5    300

# %%
df5
# Out:
#    Extra
# 0      1
# 1      2
# 2      3

# %%
pd.concat([df3, df5])
# Out:
#        Date Name  Size  Price  Extra
# 0  2017/1/3    A   3.0  100.0    NaN
# 1  2017/2/4    B   4.0  200.0    NaN
# 2  2017/3/5    A   5.0  300.0    NaN
# 0       NaN  NaN   NaN    NaN    1.0
# 1       NaN  NaN   NaN    NaN    2.0
# 2       NaN  NaN   NaN    NaN    3.0
