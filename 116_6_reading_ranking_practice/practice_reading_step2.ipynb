# %%
import pandas as pd
df = pd.read_csv("dataset/reading.txt", sep=" ", encoding="shift_jis")
df.head()
# Out:
#            日付   クラス  出席番号            タイトル  ページ数
# 0  2021-10-01  3年A組     1  ハバタンとフカタンの迷路の旅    49
# 1  2021-10-01    4B    24      キューちゃん海へゆく    67
# 2  2021-10-01  4年A組    20     キューちゃん、海へ行く     3
# 3  2021-10-01    4A    11     キューちゃん、海へ行く    40
# 4  2021-10-01    4B    23  ハバタンとフカタンの迷路の旅    41

# %%
valid_title = "キューちゃん海へゆく"
valid_title
# Out:
# 'キューちゃん海へゆく'

# %%
for char in ["-", "年", "組"]:
    df["クラス"] = df["クラス"].str.replace(char, "", regex=False)
df.head()
# Out:
#            日付 クラス  出席番号            タイトル  ページ数
# 0  2021-10-01  3A     1  ハバタンとフカタンの迷路の旅    49
# 1  2021-10-01  4B    24      キューちゃん海へゆく    67
# 2  2021-10-01  4A    20     キューちゃん、海へ行く     3
# 3  2021-10-01  4A    11     キューちゃん、海へ行く    40
# 4  2021-10-01  4B    23  ハバタンとフカタンの迷路の旅    41

# %%
df["クラス"].unique()
# Out:
# array(['3A', '4B', '4A', '3B', '3C'], dtype=object)

# %%
df.loc[df["タイトル"].str.contains("キューちゃん"), "タイトル"] = valid_title
df["タイトル"].unique()
# Out:
# array(['ハバタンとフカタンの迷路の旅', 'キューちゃん海へゆく', 'へびとアルゴリズム'], dtype=object)

# %%
df["学年"] = df["クラス"].str[0] + "年"
df.head()
# Out:
#            日付 クラス  出席番号            タイトル  ページ数  学年
# 0  2021-10-01  3A     1  ハバタンとフカタンの迷路の旅    49  3年
# 1  2021-10-01  4B    24      キューちゃん海へゆく    67  4年
# 2  2021-10-01  4A    20      キューちゃん海へゆく     3  4年
# 3  2021-10-01  4A    11      キューちゃん海へゆく    40  4年
# 4  2021-10-01  4B    23  ハバタンとフカタンの迷路の旅    41  4年

# %%
df["組"] = df["クラス"].str[1] + "組"
df.head()
# Out:
#            日付 クラス  出席番号            タイトル  ページ数  学年   組
# 0  2021-10-01  3A     1  ハバタンとフカタンの迷路の旅    49  3年  A組
# 1  2021-10-01  4B    24      キューちゃん海へゆく    67  4年  B組
# 2  2021-10-01  4A    20      キューちゃん海へゆく     3  4年  A組
# 3  2021-10-01  4A    11      キューちゃん海へゆく    40  4年  A組
# 4  2021-10-01  4B    23  ハバタンとフカタンの迷路の旅    41  4年  B組

# %%
display(df.head())
# Out:
#            日付 クラス  出席番号            タイトル  ページ数  学年   組
# 0  2021-10-01  3A     1  ハバタンとフカタンの迷路の旅    49  3年  A組
# 1  2021-10-01  4B    24      キューちゃん海へゆく    67  4年  B組
# 2  2021-10-01  4A    20      キューちゃん海へゆく     3  4年  A組
# 3  2021-10-01  4A    11      キューちゃん海へゆく    40  4年  A組
# 4  2021-10-01  4B    23  ハバタンとフカタンの迷路の旅    41  4年  B組

# %%
display(df["クラス"].unique())
# Out:
# array(['3A', '4B', '4A', '3B', '3C'], dtype=object)

# %%
display(df["タイトル"].unique())
# Out:
# array(['ハバタンとフカタンの迷路の旅', 'キューちゃん海へゆく', 'へびとアルゴリズム'], dtype=object)

# %%
df["クラス"] = df["クラス"].str.strip()
df["クラス"] = df["クラス"].str.upper()

for char in ["-", "年", "組"]:
    df["クラス"] = df["クラス"].str.replace(char, "", regex=False)
    
valid_classes = ["3A", "3B", "3C", "4A", "4B", "4C"]
df.loc[~df["クラス"].isin(valid_classes), "クラス"].unique()
# Out:
# array([], dtype=object)
