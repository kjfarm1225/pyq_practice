# %% [markdown]
# 「190-1: NumPyの使い方を学ぼう」 2問目

# %%
import numpy as np

# %%
# 配列の要素の絶対値を求める
a = [[-3, -2, -1], [0, 1, 2]]
np.abs(a)
# Out:
# array([[3, 2, 1],
#        [0, 1, 2]])

# %%
b = np.linspace(-1, 1, 10)
b
# Out:
# array([-1.        , -0.77777778, -0.55555556, -0.33333333, -0.11111111,
#         0.11111111,  0.33333333,  0.55555556,  0.77777778,  1.        ])

# %%
np.sin(b)
# Out:
# array([-0.84147098, -0.70169788, -0.52741539, -0.3271947 , -0.11088263,
#         0.11088263,  0.3271947 ,  0.52741539,  0.70169788,  0.84147098])

# %%
c = np.arange(1, 4)
c
# Out:
# array([1, 2, 3])

# %%
# 配列cに対してネイピア数を底とする自然対数logを計算する
np.log(c)
# Out:
# array([0.        , 0.69314718, 1.09861229])

# %%
x = np.array([[1, 2, 3]])
x
x + 10
# Out:
# array([[11, 12, 13]])

# %%
# 配列xと行列yを足す
y = np.array([[10, 20, 30], [40, 50, 60]])
y
y.shape
#x + y
# Out:
# (2, 3)

# %%
np.mean(y)
y - np.mean(y)
# Out:
# array([[-25., -15.,  -5.],
#        [  5.,  15.,  25.]])

# %%
# 配列xのすべての要素を2倍する
x * 2
# Out:
# array([[2, 4, 6]])

# %%
# 配列xと行列yを掛ける
x * y
# Out:
# array([[ 10,  40,  90],
#        [ 40, 100, 180]])

# %%
# 配列xを行列yで割る
x / y
# Out:
# array([[0.1  , 0.1  , 0.1  ],
#        [0.025, 0.04 , 0.05 ]])

# %%
z = np.array([9, 8, 0])
z
# Out:
# array([9, 8, 0])

# %%
x / (z + 1e-6)
# Out:
# array([[1.11111099e-01, 2.49999969e-01, 3.00000000e+06]])

# %%
# 配列xと行列y1の行列の積
y1 = y.reshape((3, 2))
y1
x @ y1
# Out:
# array([[220, 280]])

# %%
# 行列y2と配列xの行列の積
y2 = y.reshape((6, 1))
y2
y2 @ x
# Out:
# array([[ 10,  20,  30],
#        [ 20,  40,  60],
#        [ 30,  60,  90],
#        [ 40,  80, 120],
#        [ 50, 100, 150],
#        [ 60, 120, 180]])

# %%
# 行列yの各要素が15より小さいか判定
y
print(y)
y < 15
# Out:
# [[10 20 30]
#  [40 50 60]]
# array([[ True, False, False],
#        [False, False, False]])

# %%
# 配列xと行列yを比較して、要素ごとに等しいかを出力する行列
print(x)
print(y)
x == y
x1 = np.array([1, 2, 3])
# Out:
# [[1 2 3]]
# [[10 20 30]
#  [40 50 60]]

# %%
# 配列xとx1が同じ要素で構成されているか判定
np.allclose(x, x1)
x2 = x + 0.5
x2
# Out:
# array([[1.5, 2.5, 3.5]])

# %%
# 配列xとx2の各要素の誤差が0.3以内か判定
