# %% [markdown]
# ##　実務演習問題　完成版

# %%
import numpy as np

# %%
defects = np.array([12, 18, 9, 25, 21, 10])
defects
# Out:
# array([12, 18,  9, 25, 21, 10])

# %%
production = np.array([1000, 1200, 1200, 1300, 1250, 1150])
production
# Out:
# array([1000, 1200, 1200, 1300, 1250, 1150])

# %%
months = np.arange(1, 7)
months
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
first_half_defects = defects[:3]
first_half_defects
# Out:
# array([12, 18,  9])

# %%
second_half_defects = defects[3:]
second_half_defects
# Out:
# array([25, 21, 10])

# %%
quality_table = np.vstack([defects, production])
quality_table
# Out:
# array([[  12,   18,    9,   25,   21,   10],
#        [1000, 1200, 1200, 1300, 1250, 1150]])

# %%
check_line = np.linspace(0, 1, 5)
check_line
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
mdstack = np.vstack([months, defects])
mdstack
# Out:
# array([[ 1,  2,  3,  4,  5,  6],
#        [12, 18,  9, 25, 21, 10]])

# %%
monster_months = months[defects >= 20]
monster_months
# Out:
# array([4, 5])

# %%
monster_defects = defects[defects >=20]
monster_defects
# Out:
# array([25, 21])
