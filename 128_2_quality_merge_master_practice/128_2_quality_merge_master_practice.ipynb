# %%
import pandas as pd

# %%
df_defect = pd.DataFrame(
    [
        ["2026-06", "MELMB", "LCM-A", "点灯不良", 18],
        ["2026-06", "WSE", "LCM-B", "ショート", 32],
        ["2026-06", "GSE", "LCM-C", "外観キズ", 7],
        ["2026-06", "MELMB", "LCM-A", "ちらつき", 12],
        ["2026-06", "WSE", "LCM-D", "コネクタ浮き", 5],
    ],
    columns=[
        "month",
        "site",
        "product",
        "defect_type",
        "defect_qty",
    ],
)
df_defect
# Out:
#      month   site product defect_type  defect_qty
# 0  2026-06  MELMB   LCM-A        点灯不良          18
# 1  2026-06    WSE   LCM-B        ショート          32
# 2  2026-06    GSE   LCM-C        外観キズ           7
# 3  2026-06  MELMB   LCM-A        ちらつき          12
# 4  2026-06    WSE   LCM-D      コネクタ浮き           5

# %%
df_product_master = pd.DataFrame(
    [
        ["LCM-A", "ヘッドランプ", "品質保証1課"],
        ["LCM-B", "リアランプ", "品質保証2課"],
        ["LCM-C", "ルームランプ", "品質保証3課"],
        ["LCM-D", "ヘッドランプ", "品質保証1課"],
        ["LCM-X", "試作品", "開発部"],
    ],
    columns=[
        "product",
        "product_category",
        "owner_department",
    ],
)
df_product_master
# Out:
#   product product_category owner_department
# 0   LCM-A           ヘッドランプ           品質保証1課
# 1   LCM-B            リアランプ           品質保証2課
# 2   LCM-C           ルームランプ           品質保証3課
# 3   LCM-D           ヘッドランプ           品質保証1課
# 4   LCM-X              試作品              開発部

# %%
df_result = df_defect.merge(df_product_master, on="product")

# %%
df_result
# Out:
#      month   site product defect_type  defect_qty product_category  \
# 0  2026-06  MELMB   LCM-A        点灯不良          18           ヘッドランプ
# 1  2026-06    WSE   LCM-B        ショート          32            リアランプ
# 2  2026-06    GSE   LCM-C        外観キズ           7           ルームランプ
# 3  2026-06  MELMB   LCM-A        ちらつき          12           ヘッドランプ
# 4  2026-06    WSE   LCM-D      コネクタ浮き           5           ヘッドランプ
#
#   owner_department
# 0           品質保証1課
# 1           品質保証2課
# 2           品質保証3課
# 3           品質保証1課
# 4           品質保証1課

# %%
df_ranking = df_result.sort_values("defect_qty", ascending=False)
df_ranking
# Out:
#      month   site product defect_type  defect_qty product_category  \
# 1  2026-06    WSE   LCM-B        ショート          32            リアランプ
# 0  2026-06  MELMB   LCM-A        点灯不良          18           ヘッドランプ
# 3  2026-06  MELMB   LCM-A        ちらつき          12           ヘッドランプ
# 2  2026-06    GSE   LCM-C        外観キズ           7           ルームランプ
# 4  2026-06    WSE   LCM-D      コネクタ浮き           5           ヘッドランプ
#
#   owner_department
# 1           品質保証2課
# 0           品質保証1課
# 3           品質保証1課
# 2           品質保証3課
# 4           品質保証1課
