# %%
import pandas as pd

df = pd.read_csv(
    "visitors_sample.csv",
    index_col="日付",
    parse_dates=["日付"]
)
df.head()
# Out:
#             来店者数     売上
# 日付
# 2021-01-01   120  85000
# 2021-01-02    98  72000
# 2021-01-03   135  91000
# 2021-01-04   110  83000
# 2021-01-05    90  69000
