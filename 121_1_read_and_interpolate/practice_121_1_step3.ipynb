# %%
# %run practice_121_1_step2.ipynb
df_sale.head()
# Out:
#             Num Product  Price    Sale
# Date
# 2017-01-03  1.0       B   1200  1200.0
# 2017-01-06  2.0       B   1200  2400.0
# 2017-01-07  1.0       A   1000  1000.0
# 2017-01-11  2.0       A   1000  2000.0
# 2017-01-12  2.0       B   1200  2400.0

# %%
df_sale["Month"] = df_sale.index.month
df_sale.head()
# Out:
#             Num Product  Price    Sale  Month
# Date
# 2017-01-03  1.0       B   1200  1200.0      1
# 2017-01-06  2.0       B   1200  2400.0      1
# 2017-01-07  1.0       A   1000  1000.0      1
# 2017-01-11  2.0       A   1000  2000.0      1
# 2017-01-12  2.0       B   1200  2400.0      1

# %%
df_sale_pivot = df_sale.pivot_table(
    values="Sale",
    index="Month",
    columns="Product",
    aggfunc="sum"
)
df_sale_pivot
# Out:
# Product        A        B
# Month
# 1         8000.0  20400.0
# 2        32500.0  20400.0
# 3        40000.0  34800.0

# %%
df_sale_pivot.plot.bar()
# Out:
# <Axes: xlabel='Month'>

# %%
df_num_pivot = df_sale.pivot_table(
    values="Num",
    index="Month",
    columns="Product",
    aggfunc="sum"
)
df_num_pivot
# Out:
# Product     A     B
# Month
# 1         8.0  17.0
# 2        32.5  17.0
# 3        40.0  29.0

# %%
df_sale_pivot.plot();

# %%
df_product_pivot = df_sale.pivot_table(
    values="Sale",
    index="Product",
    aggfunc="sum"
)
df_product_pivot
# Out:
#             Sale
# Product
# A        80500.0
# B        75600.0
