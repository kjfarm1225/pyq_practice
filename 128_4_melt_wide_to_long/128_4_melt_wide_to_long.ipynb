# %% [markdown]
# ###### 128_4_melt_wide_to_long

# %%
import pandas as pd

# %%
index = pd.Index(["Alice", "Bob"], name="Name")
columns = pd.Index(["国語", "数学"], name="Subject")
data = [[80, 72,], [65, 92]]

df = pd.DataFrame(data, index=index, columns=columns)
df
# Out:
# Subject  国語  数学
# Name
# Alice    80  72
# Bob      65  92

# %%
dfm = df.melt(value_name="Point", ignore_index=False)
dfm
# Out:
#       Subject  Point
# Name
# Alice      国語     80
# Bob        国語     65
# Alice      数学     72
# Bob        数学     92

# %%
df_result = dfm.reset_index()
df_result
# Out:
#     Name Subject  Point
# 0  Alice      国語     80
# 1    Bob      国語     65
# 2  Alice      数学     72
# 3    Bob      数学     92
