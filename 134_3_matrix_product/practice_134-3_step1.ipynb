# %%
import numpy as np

# %%
recipe = np.array(
    [
        [200, 100, 50],
        [150, 150, 100],
    ]
)

# %%
recipe.shape
# Out:
# (2, 3)

# %%
ingred = np.array(
    [
        [0.10, 0.3],
        [0.05, 0.2],
        [0.20, 0.15],
    ]
)

# %%
ingred.shape
# Out:
# (3, 2)

# %%
summary = recipe @ ingred

# %%
summary.shape
# Out:
# (2, 2)

# %%
summary
# Out:
# array([[35. , 87.5],
#        [42.5, 90. ]])

# %%
print(recipe.shape)
print(ingred.shape)
# Out:
# (2, 3)
# (3, 2)

# %%
import numpy as np

recipe = np.array(
    [
        [200, 100, 50],
        [150, 150, 100],
        [100, 200, 150],
    ]
)

ingred = np.array(
    [
        [0.10, 0.3],
        [0.05, 0.2],
        [0.20, 0.15],
    ]
)

summary = recipe @ ingred
summary
# Out:
# array([[35. , 87.5],
#        [42.5, 90. ],
#        [50. , 92.5]])
