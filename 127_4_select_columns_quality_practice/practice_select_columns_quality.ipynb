# %% [markdown]
# ###### 実務問題

# %%
import pandas as pd

df_quality = pd.DataFrame(
    [
        ["2026-06", "MELMB", "Lamp-A", "不点灯", 12000, 18, 1500.0, "インパルス検査強化", "対応中"],
        ["2026-06", "WSE", "Lamp-B", "ちらつき", 8000, 32, 4000.0, "工程条件確認", "未対応"],
        ["2026-06", "GSE", "Lamp-C", "外観不良", 15000, 9, 600.0, "作業標準見直し", "完了"],
        ["2026-07", "MELMB", "Lamp-A", "不点灯", 11000, 25, 2272.7, "検査電圧見直し", "対応中"],
        ["2026-07", "WSE", "Lamp-B", "ショート", 9000, 45, 5000.0, "設備点検", "未対応"],
        ["2026-07", "GSE", "Lamp-C", "外観不良", 14000, 7, 500.0, "作業者教育", "完了"],
    ],
    columns=[
        "month",
        "site",
        "product",
        "defect_type",
        "production_qty",
        "defect_qty",
        "ppm",
        "countermeasure",
        "status",
    ],
)

df_basic = df_quality[["month", "site", "product"]]
df_basic

df_defect_check = df_quality[["site", "product", "defect_type", "defect_qty"]]
df_defect_check

df_report = df_quality[["month", "site", "product", "defect_qty", "ppm", "status"]]
df_report

df_countermeasure = df_quality[["site", "product", "defect_type", "countermeasure", "status"]]
df_countermeasure

df_basic
df_defect_check
df_report
df_countermeasure
# Out:
#     site product defect_type countermeasure status
# 0  MELMB  Lamp-A         不点灯      インパルス検査強化    対応中
# 1    WSE  Lamp-B        ちらつき         工程条件確認    未対応
# 2    GSE  Lamp-C        外観不良        作業標準見直し     完了
# 3  MELMB  Lamp-A         不点灯        検査電圧見直し    対応中
# 4    WSE  Lamp-B        ショート           設備点検    未対応
# 5    GSE  Lamp-C        外観不良          作業者教育     完了
