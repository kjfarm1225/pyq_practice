# %%
import pandas as pd

# %%
df = pd.DataFrame([[0], [1]], columns=["A"])
df
# Out:
#    A
# 0  0
# 1  1

# %%
import pandas as pd

df = pd.DataFrame([[1], [0]], columns=["A"])
df
# Out:
#    A
# 0  1
# 1  0

# %%
df = pd.DataFrame([[0], [1]], columns=["B"])
df
# Out:
#    B
# 0  0
# 1  1

# %%
import pandas as pd

data = [[0], [1], [0]]
col_names = ["A"]
df = pd.DataFrame(data, columns=col_names)
df
# Out:
#    A
# 0  0
# 1  1
# 2  0

# %%
import pandas as pd

df = pd.DataFrame([[0], [1], [0]], columns=["A"])
df
# Out:
#    A
# 0  0
# 1  1
# 2  0

# %%
import pandas as pd

df = pd.DataFrame([[0], [1]], columns=["X"])
df
# Out:
#    X
# 0  0
# 1  1

# %%
import pandas as pd
df = pd.DataFrame([[0], [1]], columns=["Test"])
df
# Out:
#    Test
# 0     0
# 1     1
