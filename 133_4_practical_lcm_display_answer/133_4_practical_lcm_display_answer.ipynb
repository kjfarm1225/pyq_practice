# %% [markdown]
# ###### 133_4_practical_lcm_display_answer.ipynb

# %%
import pandas as pd

# %%
df = pd.read_csv(
    "dataset/lcm_due_style_practice.csv",
)
display(df.head(5))
# Out:
#    no   site  model defect_category defect_count    due_date status priority  \
# 0   1    GSE  LCM-A            点灯不良            2  2026-08-01    対応中        中
# 1   2    WSE  LCM-B            外観不良            6  2026-08-03    未対応        高
# 2   3   META  LCM-A            寸法不良            1  2026-08-10     完了        低
# 3   4  MELAC  LCM-C              異音            8  2026-07-30    未対応        高
# 4   5    GSE  LCM-B            点灯不良            0  2026-08-15     完了        低
#
#   comment
# 0    通常確認
# 1    期限注意
# 2    問題なし
# 3    期限超過
# 4    再発なし

# %%
df["defect_count_raw"] = df["defect_count"]
df["due_date_raw"] = df["due_date"]

# %%
# cell4
df["defect_count_clean"] = (
    df["defect_count"]
    .astype(str)
    .str.strip()
)

df["due_date_clean"] = (
    df["due_date"]
    .astype(str)
    .str.strip()
    .str.replace("/", "-", regex=False)
)

# %%
df[["due_date", "due_date_clean"]]
# Out:
#      due_date due_date_clean
# 0  2026-08-01     2026-08-01
# 1  2026-08-03     2026-08-03
# 2  2026-08-10     2026-08-10
# 3  2026-07-30     2026-07-30
# 4  2026-08-15     2026-08-15
# 5  2026/08/05     2026-08-05
# 6  2026-08-08     2026-08-08
# 7         未入力            未入力
# 8     NG_DATE        NG_DATE
# 9  2026-08-02     2026-08-02

# %%
#cell5
df["defect_count_num"] = pd.to_numeric(
    df["defect_count_clean"],
    errors="coerce",
)

# %%
df[
    [
        "defect_count_clean",
        "defect_count_num",
    ]
].dtypes
# Out:
# defect_count_clean     object
# defect_count_num      float64
# dtype: object

# %%
#cell 6
df["due_date_dt"] = pd.to_datetime(
    df["due_date_clean"],
    errors="coerce",
)

# %%
df[
    [
        "due_date_clean",
        "due_date_dt",
    ]
].dtypes
# Out:
# due_date_clean            object
# due_date_dt       datetime64[ns]
# dtype: object

# %%
#cell7
base_date = pd.Timestamp("2026-08-05")

# %%
base_date
# Out:
# Timestamp('2026-08-05 00:00:00')

# %%
#cell 8
df["is_count_ng"] = df["defect_count_num"].isna()
df["is_date_ng"] = df["due_date_dt"].isna()
df["is_overdue"] = df["due_date_dt"].notna() & (df["due_date_dt"] < base_date)
df["is_not_started"] = df["status"] == "未対応"
df["is_status_unknown"] = df["status"] == "不明"
df["is_high_priority"] = df["priority"] == "高"
df["is_many_defects"] = df["defect_count_num"] >= 5

# %%
#cell 9
def make_review_reason(row):
    reasons = []

    if row["is_count_ng"]:
        reasons.append("件数NG")

    if row["is_date_ng"]:
        reasons.append("日付NG")

    if row["is_overdue"]:
        reasons.append("期限超過")

    if row["is_not_started"]:
        reasons.append("未対応")

    if row["is_status_unknown"]:
        reasons.append("ステータス不明")

    if row["is_high_priority"]:
        reasons.append("高優先度")

    if row["is_many_defects"]:
        reasons.append("件数5以上")

    return " / ".join(reasons)

df["review_reason"] = df.apply(
    make_review_reason,
    axis=1,
)

#cell 10

review_condition = (
    df["is_count_ng"]
    | df["is_date_ng"]
    | df["is_overdue"]
    | df["is_not_started"]
    | df["is_status_unknown"]
    | df["is_high_priority"]
    | df["is_many_defects"]
)

df_review = df[review_condition].copy()
df_review
# Out:
#    no   site  model defect_category defect_count    due_date status priority  \
# 0   1    GSE  LCM-A            点灯不良            2  2026-08-01    対応中        中
# 1   2    WSE  LCM-B            外観不良            6  2026-08-03    未対応        高
# 3   4  MELAC  LCM-C              異音            8  2026-07-30    未対応        高
# 6   7   META  LCM-B            寸法不良          未入力  2026-08-08    未対応        高
# 7   8  MELAC  LCM-A              異音            5         未入力    対応中        中
# 8   9    GSE  LCM-C            点灯不良            7     NG_DATE     完了        高
# 9  10    WSE  LCM-A            外観不良            2  2026-08-02     不明        中
#
#    comment defect_count_raw  ... defect_count_num due_date_dt is_count_ng  \
# 0     通常確認                2  ...              2.0  2026-08-01       False
# 1     期限注意                6  ...              6.0  2026-08-03       False
# 3     期限超過                8  ...              8.0  2026-07-30       False
# 6    件数未入力              未入力  ...              NaN  2026-08-08        True
# 7    期限未入力                5  ...              5.0         NaT       False
# 8     日付NG                7  ...              7.0         NaT       False
# 9  ステータス不明                2  ...              2.0  2026-08-02       False
#
#    is_date_ng is_overdue  is_not_started  is_status_unknown  is_high_priority  \
# 0       False       True           False              False             False
# 1       False       True            True              False              True
# 3       False       True            True              False              True
# 6       False      False            True              False              True
# 7        True      False           False              False             False
# 8        True      False           False              False              True
# 9       False       True           False               True             False
#
#    is_many_defects              review_reason
# 0            False                       期限超過
# 1             True  期限超過 / 未対応 / 高優先度 / 件数5以上
# 3             True  期限超過 / 未対応 / 高優先度 / 件数5以上
# 6            False          件数NG / 未対応 / 高優先度
# 7             True               日付NG / 件数5以上
# 8             True        日付NG / 高優先度 / 件数5以上
# 9            False             期限超過 / ステータス不明
#
# [7 rows x 23 columns]

# %%
display_cols = [
    "no",
    "site",
    "model",
    "defect_category",
    "defect_count",
    "due_date",
    "status",
    "priority",
    "comment",
    "review_reason",
]

df_review_display = df_review[display_cols].copy()
print("===確認対象データ 全体===")
display(df_review_display)
# Out:
# ===確認対象データ 全体===
#    no   site  model defect_category defect_count    due_date status priority  \
# 0   1    GSE  LCM-A            点灯不良            2  2026-08-01    対応中        中
# 1   2    WSE  LCM-B            外観不良            6  2026-08-03    未対応        高
# 3   4  MELAC  LCM-C              異音            8  2026-07-30    未対応        高
# 6   7   META  LCM-B            寸法不良          未入力  2026-08-08    未対応        高
# 7   8  MELAC  LCM-A              異音            5         未入力    対応中        中
# 8   9    GSE  LCM-C            点灯不良            7     NG_DATE     完了        高
# 9  10    WSE  LCM-A            外観不良            2  2026-08-02     不明        中
#
#    comment              review_reason
# 0     通常確認                       期限超過
# 1     期限注意  期限超過 / 未対応 / 高優先度 / 件数5以上
# 3     期限超過  期限超過 / 未対応 / 高優先度 / 件数5以上
# 6    件数未入力          件数NG / 未対応 / 高優先度
# 7    期限未入力               日付NG / 件数5以上
# 8     日付NG        日付NG / 高優先度 / 件数5以上
# 9  ステータス不明             期限超過 / ステータス不明

# %%
#cell 12
for site in df_review_display["site"].unique():
    filtered_df = df_review_display[df_review_display["site"] == site]
    print(f"==={site}の確認データ ===")
    display(filtered_df)
# Out:
# ===GSEの確認データ ===
#    no site  model defect_category defect_count    due_date status priority  \
# 0   1  GSE  LCM-A            点灯不良            2  2026-08-01    対応中        中
# 8   9  GSE  LCM-C            点灯不良            7     NG_DATE     完了        高
#
#   comment        review_reason
# 0    通常確認                 期限超過
# 8    日付NG  日付NG / 高優先度 / 件数5以上
# ===WSEの確認データ ===
#    no site  model defect_category defect_count    due_date status priority  \
# 1   2  WSE  LCM-B            外観不良            6  2026-08-03    未対応        高
# 9  10  WSE  LCM-A            外観不良            2  2026-08-02     不明        中
#
#    comment              review_reason
# 1     期限注意  期限超過 / 未対応 / 高優先度 / 件数5以上
# 9  ステータス不明             期限超過 / ステータス不明
# ===MELACの確認データ ===
#    no   site  model defect_category defect_count    due_date status priority  \
# 3   4  MELAC  LCM-C              異音            8  2026-07-30    未対応        高
# 7   8  MELAC  LCM-A              異音            5         未入力    対応中        中
#
#   comment              review_reason
# 3    期限超過  期限超過 / 未対応 / 高優先度 / 件数5以上
# 7   期限未入力               日付NG / 件数5以上
# ===METAの確認データ ===
#    no  site  model defect_category defect_count    due_date status priority  \
# 6   7  META  LCM-B            寸法不良          未入力  2026-08-08    未対応        高
#
#   comment      review_reason
# 6   件数未入力  件数NG / 未対応 / 高優先度

# %%
for status in df_review_display["status"].unique():
    filtered_df = df_review_display[df_review_display["status"] == status]

    print(f"==={status}の確認対象データ===")
    display(filtered_df)
# Out:
# ===対応中の確認対象データ===
#    no   site  model defect_category defect_count    due_date status priority  \
# 0   1    GSE  LCM-A            点灯不良            2  2026-08-01    対応中        中
# 7   8  MELAC  LCM-A              異音            5         未入力    対応中        中
#
#   comment review_reason
# 0    通常確認          期限超過
# 7   期限未入力  日付NG / 件数5以上
# ===未対応の確認対象データ===
#    no   site  model defect_category defect_count    due_date status priority  \
# 1   2    WSE  LCM-B            外観不良            6  2026-08-03    未対応        高
# 3   4  MELAC  LCM-C              異音            8  2026-07-30    未対応        高
# 6   7   META  LCM-B            寸法不良          未入力  2026-08-08    未対応        高
#
#   comment              review_reason
# 1    期限注意  期限超過 / 未対応 / 高優先度 / 件数5以上
# 3    期限超過  期限超過 / 未対応 / 高優先度 / 件数5以上
# 6   件数未入力          件数NG / 未対応 / 高優先度
# ===完了の確認対象データ===
#    no site  model defect_category defect_count due_date status priority  \
# 8   9  GSE  LCM-C            点灯不良            7  NG_DATE     完了        高
#
#   comment        review_reason
# 8    日付NG  日付NG / 高優先度 / 件数5以上
# ===不明の確認対象データ===
#    no site  model defect_category defect_count    due_date status priority  \
# 9  10  WSE  LCM-A            外観不良            2  2026-08-02     不明        中
#
#    comment   review_reason
# 9  ステータス不明  期限超過 / ステータス不明
