# %% [markdown]
# ## 135-3: NumPyで乱数を作ろう

# %%
import numpy as np

# %%
rng = np.random.default_rng()

# %%
rnd1 = rng.random(10)

# %%
rnd1
# Out:
# array([0.96918828, 0.4583162 , 0.99023363, 0.86345669, 0.14028979,
#        0.60136802, 0.21510019, 0.69239569, 0.96591481, 0.59641994])

# %%
rnd2 = rng.random((2, 5))

# %%
rnd2
# Out:
# array([[0.13015604, 0.01224054, 0.37581214, 0.2224207 , 0.60574245],
#        [0.47053909, 0.07615925, 0.53177253, 0.52671549, 0.03253423]])

# %%
rng.random()
# Out:
# 0.029830732533360105

# %%
rng.random(10)
# Out:
# array([0.78787439, 0.73572321, 0.34076559, 0.60180296, 0.73897004,
#        0.82828152, 0.54256125, 0.07822431, 0.20252105, 0.14434903])

# %%
rng.random((2, 5))
# Out:
# array([[0.62170611, 0.49688353, 0.83996525, 0.16251131, 0.02026911],
#        [0.01780264, 0.97130427, 0.61939841, 0.82229905, 0.1057075 ]])

# %%
rnd3 = rng.uniform(3, 8, 10)
rnd3
# Out:
# array([5.04830056, 7.14973941, 4.95782482, 5.08993471, 7.97753168,
#        3.83852896, 7.78534225, 3.7901578 , 3.65305309, 6.19936268])

# %%
rnd4 = rng.uniform(3, 8, (2, 5))
rnd4
# Out:
# array([[7.4554366 , 7.770471  , 5.37906981, 5.65988666, 7.64917507],
#        [4.16169469, 5.26559834, 4.98406245, 4.12815699, 5.07298364]])

# %%
rnd5 = rng.integers(3, 8, 10)
rnd5
# Out:
# array([7, 7, 4, 5, 5, 6, 7, 5, 5, 6])

# %%
rng.random(10)
# Out:
# array([0.67714223, 0.56001154, 0.6395525 , 0.22733974, 0.53120674,
#        0.37040968, 0.39007661, 0.09471726, 0.09592915, 0.36640928])

# %%
rng.uniform(3, 8, 10)
# Out:
# array([7.39315318, 4.7898622 , 5.20194201, 4.66966645, 7.52027946,
#        6.20779261, 7.05648162, 5.68196751, 4.71325575, 7.01557552])

# %%
rng.integers(3, 8, 10)
# Out:
# array([6, 3, 4, 4, 5, 3, 5, 4, 6, 7])

# %%
practice1 = rng.random(10)
practice1
# Out:
# array([0.96594693, 0.23867998, 0.44809786, 0.69414427, 0.65968057,
#        0.53215174, 0.72576577, 0.57070273, 0.64737663, 0.93184   ])

# %%
practice1 = rng.random(5)
practice1
# Out:
# array([0.80309819, 0.65627357, 0.99839242, 0.23858197, 0.66198433])

# %%
practice2 = rng.uniform(10, 20, 6)
practice2
# Out:
# array([12.84158321, 11.86337395, 14.00946983, 17.80086568, 10.14526075,
#        18.81725093])

# %%
practice3 = rng.integers(1, 7, 10)
practice3
# Out:
# array([1, 6, 4, 3, 2, 4, 6, 4, 1, 3])

# %%
practice4 = rng.random((3, 4))

# %%
practice4
# Out:
# array([[0.35611632, 0.70338474, 0.88484402, 0.12199466],
#        [0.68632932, 0.45576391, 0.33852202, 0.54099323],
#        [0.74308583, 0.57294249, 0.96565808, 0.72495601]])

# %%
change1 = rng.uniform(5, 10, (2, 3))
change1
# Out:
# array([[5.37103537, 7.18900459, 5.37191176],
#        [5.69174575, 5.65648738, 6.74394032]])

# %%
change2 = rng.integers(100, 200, 5)
change2
# Out:
# array([188, 145, 196, 188, 119])

# %%
change3 = rng.random()
change3
# Out:
# 0.6142647001688724
