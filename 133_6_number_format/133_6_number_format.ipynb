# %% [markdown]
# ###### 133_6_number_format.ipynb

# %%
import pandas as pd

# %%
df = pd.read_csv(
    "dataset/ctr.csv",
)

# %%
display(df)
# Out:
#          月   表示数  クリック数     クリック率  クリック数の変化率
# 0  2022-01  2010    162  0.080597        NaN
# 1  2022-02  2140    158  0.073832  -0.024691
# 2  2022-03  2429    198  0.081515   0.253165
# 3  2022-04  2340    198  0.084615   0.000000

# %%
display(
    df.style.format(
        precision=3,
    )
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_099a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_099a4_level0_col0" class="col_heading level0 col0" >月</th>
#       <th id="T_099a4_level0_col1" class="col_heading level0 col1" >表示数</th>
#       <th id="T_099a4_level0_col2" class="col_heading level0 col2" >クリック数</th>
#       <th id="T_099a4_level0_col3" class="col_heading level0 col3" >クリック率</th>
#       <th id="T_099a4_level0_col4" class="col_heading level0 col4" >クリック数の変化率</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_099a4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_099a4_row0_col0" class="data row0 col0" >2022-01</td>
#       <td id="T_099a4_row0_col1" class="data row0 col1" >2010</td>
#       <td id="T_099a4_row0_col2" class="data row0 col2" >162</td>
#       <td id="T_099a4_row0_col3" class="data row0 col3" >0.081</td>
# ...

# %%
display(df)
# Out:
#          月   表示数  クリック数     クリック率  クリック数の変化率
# 0  2022-01  2010    162  0.080597        NaN
# 1  2022-02  2140    158  0.073832  -0.024691
# 2  2022-03  2429    198  0.081515   0.253165
# 3  2022-04  2340    198  0.084615   0.000000
