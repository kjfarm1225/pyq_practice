# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset/case_log.csv')
df
# Out:
#          Date  Num Product  Case
# 0  2017-01-03    1       B    15
# 1  2017-01-06    2       B    15
# 2  2017-01-07    1       A    15
# 3  2017-01-10    3       A    14
# 4  2017-01-12    2       B    14
# 5  2017-01-13    5       A    13
# 6  2017-01-17    4       B    13

# %%
df.plot(x="Date", y="Num")
plt.show()

# %%
df.plot(x="Date", y="Num", rot=20)
plt.show()

# %%
df.plot(x="Date", y="Num", rot=20, legend=True)
plt.show()

# %%
df.plot(x="Date", y="Case", rot=20, legend=True)
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 df.plot(x="Date", y="Case", rot=20, legend=True)
# ----> 2 plot.show()
#
# NameError: name 'plot' is not defined

# %%
df.plot(x="Date", y=["Num", "Case"], rot=20)
plt.show()
