# %% [markdown]
# ## 「135-1: NumPy配列（ndarray）の基本」 1問目

# %%
import numpy as np

# %%
scores_list_1d = [62, 90, 75, 98, 88]
scores_1d = np.array(scores_list_1d)
scores_1d
# Out:
# array([62, 90, 75, 98, 88])

# %%
type(scores_1d)
# Out:
# numpy.ndarray

# %%
scores_1d.shape
# Out:
# (5,)

# %%
scores_list_2d = [
    [62, 90, 75, 98, 88],
    [79, 78, 81, 82, 76],
    [91, 83, 90, 65, 71],
]

scores_2d = np.array(scores_list_2d)
scores_2d
# Out:
# array([[62, 90, 75, 98, 88],
#        [79, 78, 81, 82, 76],
#        [91, 83, 90, 65, 71]])

# %%
scores_2d.shape
# Out:
# (3, 5)

# %%
scores_list_3d = [
    [
        [62, 90, 75, 98, 88],
        [79, 78, 81, 82, 76],
        [91, 83, 90, 65, 71],
    ],
    [
        [73, 89, 82, 91, 83],
        [89, 85, 98, 96, 72],
        [98, 85, 92, 70, 81],
    ],
]

scores_3d = np.array(scores_list_3d)
scores_3d
# Out:
# array([[[62, 90, 75, 98, 88],
#         [79, 78, 81, 82, 76],
#         [91, 83, 90, 65, 71]],
#
#        [[73, 89, 82, 91, 83],
#         [89, 85, 98, 96, 72],
#         [98, 85, 92, 70, 81]]])

# %%
scores_3d.shape
# Out:
# (2, 3, 5)

# %%
import numpy as np

prices_list = [100, 200, 300]

prices = np.array(prices_list)
prices
# Out:
# array([100, 200, 300])

# %%
prices.shape
# Out:
# (3,)

# %%
import numpy as np

scores_list = [
    [80, 70, 90],
    [60, 75, 85],
]

scores = np.array(scores_list)
scores
# Out:
# array([[80, 70, 90],
#        [60, 75, 85]])

# %%
scores.shape
# Out:
# (2, 3)

# %%
import numpy as np

scores_list_2d = [
    [70, 80, 90],
    [60, 75, 85],
    [88, 92, 79],
    [55, 68, 72],
]

scores_2d = np.array(scores_list_2d)
scores_2d
# Out:
# array([[70, 80, 90],
#        [60, 75, 85],
#        [88, 92, 79],
#        [55, 68, 72]])

# %%
scores_2d.shape
# Out:
# (4, 3)
