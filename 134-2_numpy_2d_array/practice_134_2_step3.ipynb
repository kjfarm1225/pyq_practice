# %%
import numpy as np

prices = np.array(
    [[100, 130, 180],
     [110, 135, 190]])
prices
# Out:
# array([[100, 130, 180],
#        [110, 135, 190]])

# %%
prices.shape
# Out:
# (2, 3)

# %%
discounts_1d = np.array([10, 20, 25])
discounts_1d
# Out:
# array([10, 20, 25])

# %%
discounts_1d.shape
# Out:
# (3,)

# %%
print(prices.shape)
print(discounts_1d.shape)
# Out:
# (2, 3)
# (3,)

# %%
discounted_prices = prices - discounts_1d
discounted_prices
# Out:
# array([[ 90, 110, 155],
#        [100, 115, 165]])

# %%
discounts_2d = np.array(
    [[10, 20, 25],
     [10, 20, 25]]
)
prices - discounts_2d
# Out:
# array([[ 90, 110, 155],
#        [100, 115, 165]])

# %%
import numpy as np

prices2 = np.array(
    [[200, 300, 400],
     [250, 350, 450]]
)
prices2
# Out:
# array([[200, 300, 400],
#        [250, 350, 450]])

# %%
discounts2_1d = np.array([20, 30, 40])
discounts2_1d
# Out:
# array([20, 30, 40])

# %%
discounted_prices = prices2 - discounts2_1d
discounted_prices
# Out:
# array([[180, 270, 360],
#        [230, 320, 410]])

# %%
shipping_fees = np.array([5, 10, 15])
shipping_fees
# Out:
# array([ 5, 10, 15])

# %%
prices_with_shipping = prices + shipping_fees

# %%
prices_with_shipping
# Out:
# array([[105, 140, 195],
#        [115, 145, 205]])
