# %%
import numpy as np

prices = np.array(
    [[100, 130, 180],
     [110, 135, 190]])
prices
# Out:
# array([[100, 130, 180],
#        [110, 135, 190]])

# %%
prices.shape
# Out:
# (2, 3)

# %%
prices_with_tax = prices * 1.08
prices_with_tax
# Out:
# array([[108. , 140.4, 194.4],
#        [118.8, 145.8, 205.2]])

# %%
import numpy as np

prices2 = np.array(
    [[200, 300],
     [250, 350]])
prices2
# Out:
# array([[200, 300],
#        [250, 350]])

# %%
prices2.shape
# Out:
# (2, 2)

# %%
prices2_with_tax = prices2 * 1.08
prices2_with_tax
# Out:
# array([[216., 324.],
#        [270., 378.]])

# %%
prices_with_tax_10 = prices * 1.10
prices_with_tax_10
# Out:
# array([[110. , 143. , 198. ],
#        [121. , 148.5, 209. ]])
