# %%
import numpy as np

prices = np.array(
    [[100, 130, 180],
     [110, 135, 190]]
)
prices
# Out:
# array([[100, 130, 180],
#        [110, 135, 190]])

# %%
discounts = np.array(
    [[10, 20, 25],
     [5, 8, 10]]
)
discounts
# Out:
# array([[10, 20, 25],
#        [ 5,  8, 10]])

# %%
print(prices.shape)
# Out:
# (2, 3)

# %%
print(discounts.shape)
# Out:
# (2, 3)

# %%
prices.shape
# Out:
# (2, 3)

# %%
discounts.shape
# Out:
# (2, 3)

# %%
discounted_prices = prices - discounts
discounted_prices
# Out:
# array([[ 90, 110, 155],
#        [105, 127, 180]])

# %%
prices - discounts
# Out:
# array([[ 90, 110, 155],
#        [105, 127, 180]])

# %%
import numpy as np

prices2 = np.array(
    [[200, 300],
     [250, 350]]
)
prices2
# Out:
# array([[200, 300],
#        [250, 350]])

# %%
discounts2 = np.array(
    [[20, 30],
     [10, 50]]
)
discounts2
# Out:
# array([[20, 30],
#        [10, 50]])

# %%
discounted_prices2 = prices2 - discounts2
discounted_prices2
# Out:
# array([[180, 270],
#        [240, 300]])

# %%
increses = np.array(
    [[5, 10, 15],
     [10, 15, 20]]
)
raised_prices = prices + increses
raised_prices
# Out:
# array([[105, 140, 195],
#        [120, 150, 210]])
