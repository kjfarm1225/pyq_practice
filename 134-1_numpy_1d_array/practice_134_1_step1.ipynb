# %%
import numpy as np

# %%
prices = np.array([100 ,130 ,180])
prices
# Out:
# array([100, 130, 180])

# %%
type(prices)
# Out:
# numpy.ndarray

# %%
prices[0]
# Out:
# np.int64(100)

# %%
prices[1]
# Out:
# np.int64(130)

# %%
prices[2]
# Out:
# np.int64(180)

# %%
prices_with_tax = prices * 1.08
prices_with_tax
# Out:
# array([108. , 140.4, 194.4])

# %%
discounted_prices = prices - 10
discounted_prices
# Out:
# array([ 90, 120, 170])

# %%
import numpy as np

prices2 = np.array([200, 250, 300])
prices2_with_tax = prices2 * 1.08
prices2_with_tax
# Out:
# array([216., 270., 324.])

# %%
import numpy as np

prices3 = np.array([500, 700, 900])
discounted_prices3 = prices3 - 0.95

discounted_prices3
# Out:
# array([499.05, 699.05, 899.05])

# %%
import numpy as np

prices4 = np.array([80, 120, 160])
new_prices4 = prices4 * 20

new_prices4
# Out:
# array([1600, 2400, 3200])
