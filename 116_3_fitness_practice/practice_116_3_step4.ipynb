# %%
import pandas as pd

summary_df = pd.read_csv(
    "dataset/summary_df.csv",
    
    index_col = 0,
    parse_dates=["日付"]
)
summary_df.head()
# Out:
#             合計(分)  ストレッチ   筋トレ  ウォーキング  デイリー目標OK
# 日付
# 2022-04-01   39.6    6.1  15.1    18.4     False
# 2022-04-02   66.2   13.8  20.0    32.4      True
# 2022-04-03   53.8   10.4  17.8    25.6      True
# 2022-04-04   41.0   11.7  29.3     0.0     False
# 2022-04-05    7.5    7.5   0.0     0.0     False

# %%
print(summary_df.columns)
# Out:
# Index(['合計(分)', 'ストレッチ', '筋トレ', 'ウォーキング', 'デイリー目標OK'], dtype='object')

# %%
summary_df.head()
# Out:
#             合計(分)  ストレッチ   筋トレ  ウォーキング  デイリー目標OK
# 日付
# 2022-04-01   39.6    6.1  15.1    18.4     False
# 2022-04-02   66.2   13.8  20.0    32.4      True
# 2022-04-03   53.8   10.4  17.8    25.6      True
# 2022-04-04   41.0   11.7  29.3     0.0     False
# 2022-04-05    7.5    7.5   0.0     0.0     False

# %%
category_names = summary_df.columns[1:-1]
category_names
# Out:
# Index(['ストレッチ', '筋トレ', 'ウォーキング'], dtype='object')

# %%
summary_df[category_names].head()
# Out:
#             ストレッチ   筋トレ  ウォーキング
# 日付
# 2022-04-01    6.1  15.1    18.4
# 2022-04-02   13.8  20.0    32.4
# 2022-04-03   10.4  17.8    25.6
# 2022-04-04   11.7  29.3     0.0
# 2022-04-05    7.5   0.0     0.0

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Meiryo"

# %%
summary_df[category_names].plot.bar(
    title = "日別の運動量（分）",
    stacked = True
)
# Out:
# <Axes: title={'center': '日別の運動量（分）'}, xlabel='日付'>

# %%
summary_df["ウォーキング"] > 0
# Out:
# 日付
# 2022-04-01     True
# 2022-04-02     True
# 2022-04-03     True
# 2022-04-04    False
# 2022-04-05    False
# 2022-04-06     True
# 2022-04-07    False
# 2022-04-08    False
# 2022-04-09     True
# 2022-04-10    False
# 2022-04-11    False
# 2022-04-12     True
# 2022-04-13    False
# 2022-04-14     True
# 2022-04-15     True
# 2022-04-16     True
# 2022-04-17    False
# 2022-04-18     True
# 2022-04-19    False
# 2022-04-20     True
# 2022-04-21     True
# 2022-04-22    False
# 2022-04-23    False
# 2022-04-24    False
# 2022-04-25     True
# 2022-04-26     True
# 2022-04-27    False
# 2022-04-28     True
# 2022-04-29     True
# 2022-04-30    False
# Name: ウォーキング, dtype: bool

# %%
(summary_df["ウォーキング"] > 0).sum()
# Out:
# np.int64(16)

# %%
def count_over_0(sr):
    return (sr > 0).sum()
result_sr = summary_df.agg(count_over_0)
result_sr
# Out:
# 合計(分)       30
# ストレッチ       30
# 筋トレ         19
# ウォーキング      16
# デイリー目標OK    13
# dtype: int64

# %%
result_df = result_sr.to_frame()
result_df
# Out:
#            0
# 合計(分)     30
# ストレッチ     30
# 筋トレ       19
# ウォーキング    16
# デイリー目標OK  13

# %%
result_df = result_df.rename(columns={0: "日数"})
result_df
# Out:
#           日数
# 合計(分)     30
# ストレッチ     30
# 筋トレ       19
# ウォーキング    16
# デイリー目標OK  13

# %%
result_df = result_df.iloc[1:]
result_df
# Out:
#           日数
# ストレッチ     30
# 筋トレ       19
# ウォーキング    16
# デイリー目標OK  13

# %%
summary_df = pd.read_csv(

    "dataset/summary_df.csv",
    index_col="日付",
    parse_dates=["日付"]
)

category_names = summary_df.columns[1:-1]

summary_df[category_names].plot.ba(
    title = "日別の運動量（分）",
    stacked = True
)
# Out:
#             合計(分)  ストレッチ   筋トレ  ウォーキング  デイリー目標OK
# 日付
# 2022-04-01   39.6    6.1  15.1    18.4     False
# 2022-04-02   66.2   13.8  20.0    32.4      True
# 2022-04-03   53.8   10.4  17.8    25.6      True
# 2022-04-04   41.0   11.7  29.3     0.0     False
# 2022-04-05    7.5    7.5   0.0     0.0     False
