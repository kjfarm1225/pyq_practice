# %%
import datetime
# %run practice_120_2_step2.ipynb
# Out:
# Date datetime64[ns]
# Date datetime64[ns]
# Date datetime64[ns]
# Date datetime64[ns]

# %%
df_sale.head()
# Out:
#             Num Product  Price    Sale
# Date
# 2017-01-03  1.0       B   1200  1200.0
# 2017-01-06  2.0       B   1200  2400.0
# 2017-01-07  1.0       A   1000  1000.0
# 2017-01-11  2.0       A   1000  2000.0
# 2017-01-12  2.0       B   1200  2400.0

# %%
df_sale.loc[datetime.datetime(2017, 1, 3)]
# Out:
# Num           1.0
# Product         B
# Price        1200
# Sale       1200.0
# Name: 2017-01-03 00:00:00, dtype: object

# %%
df_sale.loc["2017/1/3"]
# Out:
# Num           1.0
# Product         B
# Price        1200
# Sale       1200.0
# Name: 2017-01-03 00:00:00, dtype: object

# %%
df_sale.iloc[0]
# Out:
# Num           1.0
# Product         B
# Price        1200
# Sale       1200.0
# Name: 2017-01-03 00:00:00, dtype: object

# %%
#df_sale.loc["2017/1/1"]

# %%
df_sale_slice = df_sale.loc["2017/1/1":"2017/1/7"]
df_sale_slice
# Out:
#             Num Product  Price    Sale
# Date
# 2017-01-03  1.0       B   1200  1200.0
# 2017-01-06  2.0       B   1200  2400.0
# 2017-01-07  1.0       A   1000  1000.0

# %%
import datetime
# %run practice_120_2_step2.ipynb
df_sale.head()
# Out:
# Date datetime64[ns]
# Date datetime64[ns]
# Date datetime64[ns]
# Date datetime64[ns]
#             Num Product  Price    Sale
# Date
# 2017-01-03  1.0       B   1200  1200.0
# 2017-01-06  2.0       B   1200  2400.0
# 2017-01-07  1.0       A   1000  1000.0
# 2017-01-11  2.0       A   1000  2000.0
# 2017-01-12  2.0       B   1200  2400.0

# %%
df_sale.loc[datetime.datetime(2017, 1, 3)]
# Out:
# Num           1.0
# Product         B
# Price        1200
# Sale       1200.0
# Name: 2017-01-03 00:00:00, dtype: object

# %%
df_sale.loc["2017/1/3"]
# Out:
# Num           1.0
# Product         B
# Price        1200
# Sale       1200.0
# Name: 2017-01-03 00:00:00, dtype: object

# %%
df_sale.iloc[0]
# Out:
# Num           1.0
# Product         B
# Price        1200
# Sale       1200.0
# Name: 2017-01-03 00:00:00, dtype: object

# %%
df_sale_slice = df_sale.loc["2017/1/1":"2017/1/7"]
df_sale_slice
# Out:
#             Num Product  Price    Sale
# Date
# 2017-01-03  1.0       B   1200  1200.0
# 2017-01-06  2.0       B   1200  2400.0
# 2017-01-07  1.0       A   1000  1000.0

# %%
df_sale.loc["2017/1/6"]
# Out:
# Num           2.0
# Product         B
# Price        1200
# Sale       2400.0
# Name: 2017-01-06 00:00:00, dtype: object

# %%
df_sale.iloc[1]
# Out:
# Num           2.0
# Product         B
# Price        1200
# Sale       2400.0
# Name: 2017-01-06 00:00:00, dtype: object

# %%
df_sale.loc["2017/1/3":"2017/1/12"]
# Out:
#             Num Product  Price    Sale
# Date
# 2017-01-03  1.0       B   1200  1200.0
# 2017-01-06  2.0       B   1200  2400.0
# 2017-01-07  1.0       A   1000  1000.0
# 2017-01-11  2.0       A   1000  2000.0
# 2017-01-12  2.0       B   1200  2400.0

# %%
df_sale_slice = df_sale.loc["2017/1/1":"2017/1/7"]
df_sale_slice.shape
# Out:
# (3, 4)

# %%
df_sale_slice
# Out:
#             Num Product  Price    Sale
# Date
# 2017-01-03  1.0       B   1200  1200.0
# 2017-01-06  2.0       B   1200  2400.0
# 2017-01-07  1.0       A   1000  1000.0
