# %%
# %run practice_120_3_step1.ipynb

df_sale.head()
# Out:
#             Num Product  Price    Sale
# Date
# 2017-01-03  1.0       B   1200  1200.0
# 2017-01-06  2.0       B   1200  2400.0
# 2017-01-07  1.0       A   1000  1000.0
# 2017-01-11  2.0       A   1000  2000.0
# 2017-01-12  2.0       B   1200  2400.0

# %%
df_sale.resample("ME").sum()
# Out:
#              Num         Product  Price     Sale
# Date
# 2017-01-31  25.0    BBAABBBBBAAB  13600  28400.0
# 2017-02-28  35.0  ABBAABAAABAABA  15000  38400.0
# 2017-03-31  69.0  AABAAABBBBBAAA  15200  74800.0

# %%
df_sale["Sale"].resample("ME").sum()
# Out:
# Date
# 2017-01-31    28400.0
# 2017-02-28    38400.0
# 2017-03-31    74800.0
# Freq: ME, Name: Sale, dtype: float64

# %%
df_sale["Sale"].plot(marker="o")
df_sale_resample = df_sale.resample("W")
df_sale_resample["Sale"].mean().plot(marker=".", style="--");

# %%
df_sale["Sale"].plot(marker="o")
df_sale["Sale"].resample("D").interpolate().plot(marker=".", style="--");

# %%
df_sale["Sale"].plot(marker="o")
df_sale["Sale"].resample("D").interpolate("quadratic").plot(marker=".", style="--");

# %%
df_sale["Sale"].plot(marker="o")
df_sale["Sale"].resample("D").interpolate("quadratic").plot(marker=".", style="--")
plt.title("Sale Trend with Quadratic Interpolation")
plt.grid(True)
