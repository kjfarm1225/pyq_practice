# %%
import pandas as pd
df = pd.read_csv("attendance.csv")
df
# Out:
#          Date  Office  Tele
# 0  2019-06-03      19    21
# 1  2019-06-04       2    38
# 2  2019-06-05      11    29
# 3  2019-06-06      15    25
# 4  2019-06-07      20    18

# %%
df.plot(x="Date", y="Office");
