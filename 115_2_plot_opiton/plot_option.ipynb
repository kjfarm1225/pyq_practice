# %%
# %matplotlib inline
import pandas as pd
df = pd.read_csv("attendance.csv")
df

# %%
df.plot(x="Date", y="Office");

# %%
# !pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.1 MB 6.3 MB/s eta 0:00:02
#    -------------- ------------------------- 2.9/8.1 MB 7.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.1 MB 8.2 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.1 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 7.9 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    -------------------------- ------------- 1.6/2.3 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 6.8 MB/s  0:00:00
# ...
#
#    -------- ------------------------------- 1/5 [fonttools]
#    -------- ------------------------------- 1/5 [fonttools]
#    -------- ------------------------------- 1/5 [fonttools]
# ...

# %%
# %matplotlib inline
import pandas as pd

df = pd.read_csv("attendance.csv")
df.plot(x="Date", y="Office");

# %%
df.plot(
    x="Date",
    y="Office",
    title="Attendances of Office",
    rot=20,
    legend=False
);
