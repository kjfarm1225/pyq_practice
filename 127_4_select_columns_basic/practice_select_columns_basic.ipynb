# %% [markdown]
# ###### 127-4: 一部の列を取得するには

# %%
import pandas as pd

df = pd.DataFrame(
    [
        ["Alice", "国語", 87],
        ["Alice", "数学", 72],
        ["Bob", "国語", 65],
        ["Bob", "数学", 92],
    ],
    columns=["Name", "Subject", "Point"],
)
df[["Name", "Subject"]]
# Out:
#     Name Subject
# 0  Alice      国語
# 1  Alice      数学
# 2    Bob      国語
# 3    Bob      数学
